# %% [markdown]
# # APPLY NAIVE BAYES ON AMAZON FINE FOOD REVIEWS

# %% [markdown]
# The Amazon Fine Food Reviews dataset consists of reviews of fine foods from Amazon.
#
# Number of reviews: 568,454 Number of users: 256,059 Number of products: 74,258 Timespan: Oct 1999 - Oct 2012 Number of Attributes/Columns in data: 10
#
# Attribute Information:
#
# Id ProductId - unique identifier for the product UserId - unqiue identifier for the user ProfileName HelpfulnessNumerator - number of users who found the review helpful HelpfulnessDenominator - number of users who indicated whether they found the review helpful or not Score - rating between 1 and 5 Time - timestamp for the review Summary - brief summary of the review Text - text of the review

# %% [markdown]
# # [1]. Reading Data

# %% [markdown]
# # [1.1] Loading the data¶

# %% [markdown]
# The dataset is available in two forms
#
# .csv file SQLite Database In order to load the data, We have used the SQLITE dataset as it is easier to query the data and visualise the data efficiently. Here as we only want to get the global sentiment of the recommendations (positive or negative), we will purposefully ignore all Scores equal to 3. If the score is above 3, then the recommendation wil be set to "positive". Otherwise, it will be set to "negative".

# %%
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")


import sqlite3
import pandas as pd
import numpy as np
import nltk
import string
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import TfidfVectorizer

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics import confusion_matrix
from sklearn import metrics
from sklearn.metrics import roc_curve, auc
from nltk.stem.porter import PorterStemmer

import re
# Tutorial about Python regular expressions: https://pymotw.com/2/re/
import string
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.stem.wordnet import WordNetLemmatizer

from gensim.models import Word2Vec
from gensim.models import KeyedVectors
import pickle


import os

# %%
# using SQLite Table to read data.
con = sqlite3.connect('./amazon-fine-food-review/database.sqlite') 

# filtering only positive and negative reviews i.e. 
# not taking into consideration those reviews with Score=3
# SELECT * FROM Reviews WHERE Score != 3 LIMIT 500000, will give top 500000 data points
# you can change the number to any other number based on your computing power

# filtered_data = pd.read_sql_query(""" SELECT * FROM Reviews WHERE Score != 3 LIMIT 500000""", con) 
# for tsne assignment you can take 5k data points

filtered_data = pd.read_sql_query(""" SELECT * FROM Reviews WHERE Score != 3 LIMIT 100000""", con) 

# Give reviews with Score>3 a positive rating(1), and reviews with a score<3 a negative rating(0).
def partition(x):
    if x < 3:
        return 0
    return 1

#changing reviews with score less than 3 to be positive and vice-versa
actualScore = filtered_data['Score']
positiveNegative = actualScore.map(partition) 
filtered_data['Score'] = positiveNegative
print("Number of data points in our data", filtered_data.shape)
filtered_data.shape
# Out:
# Number of data points in our data (100000, 10)
# (100000, 10)

# %% [markdown]
# # [2] Exploratory Data Analysis

# %% [markdown]
# # [2.1] Data Cleaning: Deduplication

# %% [markdown]
# It is observed (as shown in the table below) that the reviews data had many duplicate entries. Hence it was necessary to remove duplicates in order to get unbiased results for the analysis of the data. Following is an example:

# %%
display= pd.read_sql_query("""
SELECT *
FROM Reviews
WHERE Score != 3 AND UserId="AR5J8UI46CURR"
ORDER BY ProductID
""", con)
display.head()
# Out:
#        Id   ProductId         UserId      ProfileName  HelpfulnessNumerator  \
# 0   78445  B000HDL1RQ  AR5J8UI46CURR  Geetha Krishnan                     2
# 1  138317  B000HDOPYC  AR5J8UI46CURR  Geetha Krishnan                     2
# 2  138277  B000HDOPYM  AR5J8UI46CURR  Geetha Krishnan                     2
# 3   73791  B000HDOPZG  AR5J8UI46CURR  Geetha Krishnan                     2
# 4  155049  B000PAQ75C  AR5J8UI46CURR  Geetha Krishnan                     2
#
#    HelpfulnessDenominator  Score        Time  \
# 0                       2      5  1199577600
# 1                       2      5  1199577600
# 2                       2      5  1199577600
# 3                       2      5  1199577600
# 4                       2      5  1199577600
#
#                              Summary  \
# 0  LOACKER QUADRATINI VANILLA WAFERS
# 1  LOACKER QUADRATINI VANILLA WAFERS
# 2  LOACKER QUADRATINI VANILLA WAFERS
# 3  LOACKER QUADRATINI VANILLA WAFERS
# 4  LOACKER QUADRATINI VANILLA WAFERS
#
#                                                 Text
# 0  DELICIOUS WAFERS. I FIND THAT EUROPEAN WAFERS ...
# 1  DELICIOUS WAFERS. I FIND THAT EUROPEAN WAFERS ...
# 2  DELICIOUS WAFERS. I FIND THAT EUROPEAN WAFERS ...
# 3  DELICIOUS WAFERS. I FIND THAT EUROPEAN WAFERS ...
# 4  DELICIOUS WAFERS. I FIND THAT EUROPEAN WAFERS ...

# %% [markdown]
# As it can be seen above that same user has multiple reviews with same values for HelpfulnessNumerator, HelpfulnessDenominator, Score, Time, Summary and Text and on doing analysis it was found that
#
# ProductId=B000HDOPZG was Loacker Quadratini Vanilla Wafer Cookies, 8.82-Ounce Packages (Pack of 8)
#
# ProductId=B000HDL1RQ was Loacker Quadratini Lemon Wafer Cookies, 8.82-Ounce Packages (Pack of 8) and so on
#
# It was inferred after analysis that reviews with same parameters other than ProductId belonged to the same product just having different flavour or quantity. Hence in order to reduce redundancy it was decided to eliminate the rows having same parameters.
#
# The method used for the same was that we first sort the data according to ProductId and then just keep the first similar product review and delelte the others. for eg. in the above just the review for ProductId=B000HDL1RQ remains. This method ensures that there is only one representative for each product and deduplication without sorting would lead to possibility of different representatives still existing for the same product.

# %%
#Sorting data according to ProductId in ascending order
sorted_data=filtered_data.sort_values('ProductId', axis=0, ascending=True, inplace=False, kind='quicksort', na_position='last')

# %%
#Deduplication of entries
final=sorted_data.drop_duplicates(subset={"UserId","ProfileName","Time","Text"}, keep='first', inplace=False)
final.shape
# Out:
# (87775, 10)

# %% [markdown]
# Observation:- It was also seen that in two rows given below the value of HelpfulnessNumerator is greater than HelpfulnessDenominator which is not practically possible hence these two rows too are removed from calcualtions

# %%
display= pd.read_sql_query("""
SELECT *
FROM Reviews
WHERE Score != 3 AND Id=44737 OR Id=64422
ORDER BY ProductID
""", con)

display.head()
# Out:
#       Id   ProductId          UserId              ProfileName  \
# 0  64422  B000MIDROQ  A161DK06JJMCYF  J. E. Stephens "Jeanne"
# 1  44737  B001EQ55RW  A2V0I904FH7ABY                      Ram
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     3                       1      5  1224892800
# 1                     3                       2      4  1212883200
#
#                                         Summary  \
# 0             Bought This for My Son at College
# 1  Pure cocoa taste with crunchy almonds inside
#
#                                                 Text
# 0  My son loves spaghetti so I didn't hesitate or...
# 1  It was almost a 'love at first bite' - the per...

# %%
final=final[final.HelpfulnessNumerator<=final.HelpfulnessDenominator]

# %%
#Before starting the next phase of preprocessing lets see the number of entries left
print(final.shape)

#How many positive and negative reviews are present in our dataset?
final['Score'].value_counts()
# Out:
# (87773, 10)
# 1    73592
# 0    14181
# Name: Score, dtype: int64

# %% [markdown]
# # [3] Preprocessing¶

# %% [markdown]
# # [3.1]. Preprocessing Review Text¶

# %% [markdown]
# Now that we have finished deduplication our data requires some preprocessing before we go on further with analysis and making the prediction model.
#
# Hence in the Preprocessing phase we do the following in the order below:-
#
# Begin by removing the html tags Remove any punctuations or limited set of special characters like , or . or # etc. Check if the word is made up of english letters and is not alpha-numeric Check to see if the length of the word is greater than 2 (as it was researched that there is no adjective in 2-letters) Convert the word to lowercase Remove Stopwords Finally Snowball Stemming the word (it was obsereved to be better than Porter Stemming) After which we collect the words used to describe positive and negative reviews

# %%
import re
# Tutorial about Python regular expressions: https://pymotw.com/2/re/
import string
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.stem.wordnet import WordNetLemmatizer
import nltk

stop = set(stopwords.words('english')) #set of stopwords
sno = nltk.stem.SnowballStemmer('english') #initialising the snowball stemmer

def cleanhtml(sentence): #function to clean the word of any html-tags
    cleanr = re.compile('<.*?>')
    cleantext = re.sub(cleanr, ' ', sentence)
    return cleantext
def cleanpunc(sentence): #function to clean the word of any punctuation or special characters
    cleaned = re.sub(r'[?|!|\'|"|#]',r'',sentence)
    cleaned = re.sub(r'[.|,|)|(|\|/]',r' ',cleaned)
    return  cleaned
print(stop)
print('************************************')
print(sno.stem('tasty'))
# Out:
# {'each', 'won', 'does', 'shouldn', "mustn't", "weren't", 'between', 't', 'nor', 'mustn', 'their', 'my', 'which', 'doing', "shouldn't", 'off', 'm', 'as', 'why', 'isn', 'most', 'having', "isn't", 'should', 'all', 're', 'what', 'yourself', 'he', 'themselves', 'when', 've', 'wouldn', 'needn', 'will', 'with', 'ourselves', 'while', 'herself', 'now', 'am', 'such', 'didn', 'again', 'y', 'itself', 'to', 'she', 'if', 'only', 'myself', "doesn't", 'ain', 'or', 'then', 'wasn', 'me', 'few', 'other', 'can', 'until', 'above', 'who', "should've", 'did', "shan't", 'had', 'o', "wasn't", 'from', 'any', 'were', 'it', 'than', 'against', "wouldn't", 'you', 'yourselves', 'through', 'whom', 'where', 'how', "hadn't", 'these', 'haven', "mightn't", 'him', 'at', 'because', "hasn't", 'that', 'an', "you'd", 'have', 'her', 'its', 'this', 'no', "needn't", 'himself', 'are', 'into', 'i', 'ours', 'so', 'during', 'hadn', 'on', 'but', 'was', 'the', 'those', 'them', 'too', 'out', 'under', 'we', 'they', 'by', 'is', 'in', 'here', 'yours', 'weren', 'below', 'before', 'same', 'couldn', 'being', 'some', 'for', 'own', 'more', 'd', 'hers', "couldn't", "didn't", 'shan', 'has', 'down', 'doesn', 'aren', "aren't", 's', 'very', 'and', 'hasn', 'about', "haven't", 'there', "you've", "you're", 'll', 'a', 'been', 'just', 'our', 'of', 'his', "she's", 'do', "that'll", "you'll", 'once', 'ma', "won't", 'be', 'up', 'don', 'after', "it's", 'further', "don't", 'your', 'both', 'not', 'over', 'mightn', 'theirs'}
# ************************************
# tasti

# %%
#Code for implementing step-by-step the checks mentioned in the pre-processing phase
# this code takes a while to run as it needs to run on 500k sentences.
i=0
str1=' '
final_string=[]
all_positive_words=[] # store words from +ve reviews here
all_negative_words=[] # store words from -ve reviews here.
s=''

for sent in final['Text'].values:
    filtered_sentence=[]
    #print(sent);
    sent=cleanhtml(sent) # remove HTMl tags
    for w in sent.split():
        for cleaned_words in cleanpunc(w).split():
            if((cleaned_words.isalpha()) & (len(cleaned_words)>2)):    
                if(cleaned_words.lower() not in stop):
                    s=(sno.stem(cleaned_words.lower())).encode('utf8')
                    filtered_sentence.append(s)
                    if (final['Score'].values)[i] == 'positive': 
                        all_positive_words.append(s) #list of all words used to describe positive reviews
                    if(final['Score'].values)[i] == 'negative':
                        all_negative_words.append(s) #list of all words used to describe negative reviews reviews
                else:
                    continue
            else:
                continue 
    #print(filtered_sentence)
    str1 = b" ".join(filtered_sentence) #final string of cleaned words
    #print("***********************************************************************")
    
    final_string.append(str1)
    i+=1

# %%
final['CleanedText']=final_string
final['CleanedText']=final['CleanedText'].str.decode("utf-8")
#below the processed review can be seen in the CleanedText Column 
print('Shape of final',final.shape)
final.head()
# Out:
# Shape of final (87773, 11)
#           Id   ProductId          UserId        ProfileName  \
# 22620  24750  2734888454  A13ISQV0U9GZIC          Sandikaye
# 22621  24751  2734888454  A1C298ITT645B6  Hugh G. Pritchard
# 70677  76870  B00002N8SM  A19Q006CSFT011           Arlielle
# 70676  76869  B00002N8SM  A1FYH4S02BW7FN           wonderer
# 70675  76868  B00002N8SM   AUE8TB5VHS6ZV      eyeofthestorm
#
#        HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 22620                     1                       1      0  1192060800
# 22621                     0                       0      1  1195948800
# 70677                     0                       0      0  1288396800
# 70676                     0                       0      0  1290038400
# 70675                     0                       0      0  1306972800
#
#                                        Summary  \
# 22620                            made in china
# 22621                        Dog Lover Delites
# 70677                  only one fruitfly stuck
# 70676  Doesn't work!! Don't waste your money!!
# 70675                            A big rip off
#
#                                                     Text  \
# 22620  My dogs loves this chicken but its a product f...
# 22621  Our dogs just love them.  I saw them in a pet ...
# 70677  I had an infestation of fruitflies, they were ...
# 70676  Worst product I have gotten in long time. Woul...
# 70675  I wish I'd read the reviews before making this...
#
#                                              CleanedText
# 22620  dog love chicken product china wont buy anymor...
# 22621  dog love saw pet store tag attach regard made ...
# 70677  infest fruitfli liter everywher fli around kit...
# 70676  worst product gotten long time would rate star...
# 70675  wish read review make purchas basic cardsotck ...

# %%
time_sorted_data = final.sort_values('Time', axis=0, ascending=True, inplace=False, kind='quicksort', na_position='last')
time_sorted_data
# Out:
#            Id   ProductId          UserId  \
# 70688   76882  B00002N8SM  A32DW342WBJ6BX
# 1146     1245  B00002Z754  A29Z5PI9BW2PU3
# 1145     1244  B00002Z754  A3B8RCEI0FXFI6
# 28086   30629  B00008RCMI  A19E94CF5O1LY7
# 28087   30630  B00008RCMI  A284C7M23F0APC
# 61299   66610  B0000SY9U4  A3EEDHNHI4WNSH
# 38740   42069  B0000EIEQU  A1YMJX4YWCE6P4
# 38889   42227  B0000A0BS8  A1IU7S4HCK1XK0
# 38888   42226  B0000A0BS8  A23GFTVIETX7DS
# 10992   11991  B0000T15M8  A2928LJN5IISB4
# 28085   30628  B00008RCMI  A3AKWA5CWSKOOH
# 97546  105988  B0000DG4EJ   AVCJ3K0HFRRUM
# 96196  104537  B0000DG5B6  A1S3DOTCYJPE4O
# 62127   67497  B0000D9N7U    AQFIH82DRPMW
# 87386   95119  B0000DIYIJ  A3S4XR84R8S0TV
# 39671   43130  B0000W2SZS  A2BETN6Y2DEFZ1
# 48952   53177  B002UUJ590  A2IF5C0I5BH11F
# 28085  Ilaxi S. Patel "Editor, kidsfreesouls.com & A...                     0
# 97546                                        H. Johnson                     0
# 96196                               hervin02 "hervin02"                     0
# 62127                                   Patrick O'Brien                    26
# 87386                                   Brook Lindquist                     0
# 39671                                            Catnip                    11
# 48952                                              Kala                    17
# 24061            Rebecca of Amazon "The Rebecca Review"                     9
# 86598                         T. Reinhardt "olivia lee"                    27
# 86599                                    Joanna Daneman                    14
# 81698                            Gloriya O. Grinsteiner                     4
# 94002                              K. Moore "collegian"                     0
# 94024                                     Matt Cromwell                     8
# 94001                                        A. J. Lamb                     0
# 24220                                        Gail Cooke                     5
# 94494                                 Dipper Lips "DIP"                     3
# 7427                                         Gail Cooke                     3
# 25005                                          L Flores                     0
# 97771                                     Call Me Jonah                     5
# 94382                                       "bungfritz"                     5
# ...                                                 ...                   ...
# 42269                                           S. Guss                     0
# 76059                                     Rispir Chrone                     0
# 25112                                      Texaschick59                     0
# 29158                                      Gypsy Healer                     0
# 87843                                             Joyce                     0
# 97624                                             Jyouk                     0
# 14526                            David A. Levin "DaveL"                     0
# 14300                                           Kkrys23                     0
# 14299                                           Seagaul                     0
# 82884                                        Arnos Vale                     0
# 82885                                          Daniella                     0
# 15069                                             Harry                     0
# 43703                                           Georgie                     0
# 13539                 Christopher Whedon "the odd bead"                     0
# 52220                                   D. Pagliassotti                     0
# 55100                    Cecelia Thomas "Lady Kinrowan"                     0
# 89213                                            MTNick                     0
# 6548                                           Pen Name                     0
# 60967                                              Gina                     0
# 43268                                 Thomas R. Jackson                     0
# 16026                                         C. Furman                     0
# 90340  L. Nguyen "Always on the lookout for a good d...                     0
# 76594                                         Tony Schy                     0
# 78715                                       Denise Lake                     0
# 50708                                            C-Rush                     0
# 76593                                              Josh                     0
# 22401                                      Arvind Rajan                     0
# 56673                                             Kelly                     0
# 37074                                                cc                     0
# 5259                                               ESTY                     0
#
#        HelpfulnessDenominator  Score        Time  \
# 70688                       0      1   948672000
# 1146                        7      1   961718400
# 1145                       10      1   962236800
# 28086                       0      1  1067040000
# 28087                       0      1  1067040000
# 61299                      23      1  1067472000
# 38740                      12      1  1067558400
# 38889                       5      1  1067644800
# 38888                       5      1  1067904000
# 10992                       5      1  1067990400
# 28085                       0      1  1068076800
# 97546                       0      1  1068076800
# 96196                       0      1  1068422400
# 62127                      26      1  1068940800
# 87386                       1      1  1069113600
# 39671                      11      1  1069459200
# 48952                      18      1  1070668800
# 24061                       9      1  1071100800
# 86598                      27      1  1071705600
# 86599                      14      1  1072656000
# 81698                       6      1  1072656000
# 94002                       0      1  1072656000
# 94024                      12      1  1073692800
# 94001                       0      1  1074124800
# 24220                       6      1  1075075200
# 94494                       9      1  1075161600
# 7427                        3      1  1075420800
# 25005                       0      1  1075680000
# 97771                       7      1  1075766400
# 94382                       5      1  1075939200
# ...                       ...    ...         ...
# 42269                       0      1  1351209600
# 76059                       0      1  1351209600
# 25112                       0      1  1351209600
# 29158                       0      1  1351209600
# 87843                       0      1  1351209600
# 97624                       0      1  1351209600
# 14526                       0      1  1351209600
# 14300                       0      1  1351209600
# 14299                       0      1  1351209600
# 82884                       0      1  1351209600
# 82885                       0      1  1351209600
# 15069                       0      1  1351209600
# 43703                       0      1  1351209600
# 13539                       0      1  1351209600
# 52220                       0      1  1351209600
# 55100                       0      1  1351209600
# 89213                       0      1  1351209600
# 6548                        0      1  1351209600
# 60967                       0      1  1351209600
# 43268                       0      1  1351209600
# 16026                       0      1  1351209600
# 90340                       0      1  1351209600
# 76594                       0      1  1351209600
# 78715                       0      1  1351209600
# 50708                       0      1  1351209600
# 76593                       0      1  1351209600
# 22401                       0      0  1351209600
# 56673                       0      1  1351209600
# 37074                       0      1  1351209600
# 5259                        0      1  1351209600
#
#                                                  Summary  \
# 70688                             A sure death for flies
# 1146                                       Great Product
# 1145                      WOW Make your own 'slickers' !
# 28086         I've chewed this gum many times, but used?
# 28087                           Best sugarless gum ever!
# 61299                                              Yummy
# 38740                                  These limes rule!
# 38889                         I gave up on other coffees
# 38888                   Five stars if you like Starbucks
# 10992                             The fruits of my labor
# 28085                         Refreshing Mouth Freshner!
# 97546                                    *Yummy* *Spicy*
# 96196                                   Excellent Sauce!
# 62127                                            Try It!
# 87386                                 A very cute candy!
# 39671          Imparts wonderful, light flavor to dishes
# 48952                              Jelly Belly Overload!
# 24061                            I fell in love in Paris
# 86598       The best bread crumbs...you'll never go back
# 86599                        Essential for Tonkatsu, etc
# 81698                           everything is excellent!
# 94002                                        Simply Chai
# 94024                Chocolate Like You've Never Had It!
# 94001                                     Excellent Chai
# 24220              JUST LIKE GRANDMOTHER USED TO........
# 94494  Yes, You Can Eat It All In One Sitting and Sip...
# 7427                                    BEST BLUEBERRIES
# 25005                                    My Favorite Tea
# 97771        For those who enjoy playing with their food
# 94382      Best example of a blue cheese I've ever tried
# ...                                                  ...
# 42269                                    Great Irish Tea
# 76059                              Nice traditional chai
# 25112                                          Drink mix
# 29158                                          Delicious
# 87843              Michael Seasons Unsalted Potato Chips
# 97624  Ain't no coconut water better than Sun Tropics...
# 14526                                     Morning Coffee
# 14300                                   Love this faucet
# 14299                                      Dogs love it.
# 82884                                           Love it.
# 82885                                        I love this
# 15069                                       super coffee
# 43703                              Sleeping a lot better
# 13539                                          GREAT TEA
# 52220                                 Great for HS lunch
# 55100  Butler's chocolate is the real deal direct fro...
# 89213                                  Yummy and Healthy
# 6548                                          Delicious!
# 60967                                 So many varieties!
# 43268                                        Great food!
# 16026          Full- bodied without a bitter after-taste
# 90340                  The BEST fig spread on the market
# 76594                           Product is good, but....
# 78715                       5 Star Tea at a super price!
# 50708                                           Not bad.
# 76593                                   One of the best!
# 22401                                    bad tasting tea
# 56673                                             Chike!
# 37074                                   chocolate heaven
# 5259                                           DELICIOUS
#
#                                                     Text  \
# 70688  I bought a few of these after my apartment was...
# 1146   This was a really good idea and the final prod...
# 1145   I just received my shipment and could hardly w...
# 28086  Nothing against the product, but it does bothe...
# 28087  I love this stuff. It is sugar-free so it does...
# 61299  If you've never tried Kona coffee, Aloha Islan...
# 38740  Fresh limes are underappreciated, but a joy to...
# 38889  The grocery store has all kinds of &quot;gourm...
# 38888  This blend is one of Starbucks' gentler blends...
# 10992  When chatchi's favorite afternoon treat became...
# 28085  A tennis player hubby of mine got this pack on...
# 97546  Forget that store bought jerky.  Make your own...
# 96196  This sauce is excellent, and indeed spicy.  Th...
# 62127  If you've never had real Swiss fondue, you're ...
# 87386  This is definitely a cute product to order.  Y...
# 39671  I discovered these oils years ago, bought one ...
# 48952  I'm a huge fan of Jelly Belly jelly beans, so ...
# 24061  Yes, with this juice. Apparently I'm not the o...
# 86598  Panko bread crumbs are just awesome.  When use...
# 86599  This is the Japanese version of breadcrumb (pa...
# 81698  I highly recommend to have business with this ...
# 94002  I've tried many of packaged Chai products - li...
# 94024  I was first turned onto this chocolate when I ...
# 94001  I have searched for a great decaf chai and hav...
# 24220  For those who enjoy a rich spread for toast, c...
# 94494  And it is GOOD!!! You get a half pound of Cots...
# 7427   In the winter when fresh blueberries exceed ou...
# 25005  I love Sleepytime Tea!  I've been drinking it ...
# 97771  They're shaped like Legos and they taste like ...
# 94382  And that is no exagerration!  Roaring 40's Blu...
# ...                                                  ...
# 42269  We recently returned from a wonderful three we...
# 76059  I got hooked on this chai when I decided to gi...
# 25112  We love this drink mix it taste delicious and ...
# 29158  Individually packaged assorted rice crackers a...
# 87843  These are the best chips ever!  They are unsal...
# 97624  This is like young coconut in a can! It tastes...
# 14526  Great coffee at a good price. I'm a subscripti...
# 14300  Love this faucet.  My husband had installed th...
# 14299  This is the "all gone" treat after dinner.  It...
# 82884  I love this but think its a little to expensiv...
# 82885  It's is in my opinion the best coconut water o...
# 15069  Great coffee and so easy to brew.  This coffee...
# 43703  Hubby and I (both 63) have been drinking about...
# 13539  Rooibos Natural Red tea is something of a pers...
# 52220  Great for HS lunch, kid enjoy as a snack also,...
# 55100  Nifty hot chocolate discs added to your warm m...
# 89213  Loved the cranberry-like flavor and slightly c...
# 6548   I have ordered these raisins multiple times.  ...
# 60967  I love the assortment.  Different countries of...
# 43268  I wanted a food for a a dog with skin problems...
# 16026  This is my everyday coffee choice...a good all...
# 90340  This is my go to spread when I serve a cheese ...
# 76594  I like the product and the price point, but fo...
# 78715  This tea is very good and perfect for the pric...
# 50708  These are small and very salty. The taste is g...
# 76593  I am recently new to the Keurig world.  I've t...
# 22401  We drink a lot of tea... from all over the wor...
# 56673  Just tried the orange and iced coffee this mor...
# 37074  Excellent smooth taste. Any one who loves choc...
# 5259   Purchased this product at a local store in NY ...
#
#                                              CleanedText
# 70688  bought apart infest fruit fli hour trap mani f...
# 1146   realli good idea final product outstand use de...
# 1145   receiv shipment could hard wait tri product lo...
# 28086  noth product bother link top page buy use chew...
# 28087  love stuff doesnt rot gum tast good go buy gum...
# 61299  youv never tri kona coffe aloha island definit...
# 38740  fresh lime underappreci joy kitchen squirt lim...
# 38889  groceri store kind coffe laid one tri tast lik...
# 38888  blend one starbuck gentler blend like tast sta...
# 10992  chatchi favorit afternoon treat becam mysteri ...
# 28085  tenni player hubbi mine got pack rack opel cor...
# 97546  forget store bought jerki make premium jerki a...
# 96196  sauc excel inde spici brand also make mild ver...
# 62127  youv never real swiss fondu your realli miss s...
# 87386  definit cute product order get nice amount can...
# 39671  discov oil year ago bought one flavor thunders...
# 48952  huge fan jelli belli jelli bean realli enjoy g...
# 24061  yes juic appar person love drink lead orang ca...
# 86598  panko bread crumb awesom use bread make light ...
# 86599  japanes version breadcrumb portugues panko use...
# 81698  high recommend busi compani like job nice pric...
# 94002  ive tri mani packag chai product liquid dri so...
# 94024  first turn onto chocol visit privat mexican th...
# 94001  search great decaf chai final found excel made...
# 24220  enjoy rich spread toast crumpet english muffin...
# 94494  good get half pound cotswold english pub chees...
# 7427   winter fresh blueberri exceed food budget dri ...
# 25005  love sleepytim tea ive drink year sooth bed ta...
# 97771  theyr shape like lego tast like sweettart need...
# 94382  exagerr roar blue wonder mixtur strength subtl...
# ...                                                  ...
# 42269  recent return wonder three week excurs ireland...
# 76059  got hook chai decid give coffe still littl bit...
# 25112  love drink mix tast delici imposs find market ...
# 29158  individu packag assort rice cracker realli goo...
# 87843  best chip ever unsalt low sodium diet critic a...
# 97624  like young coconut tast like young coconut fre...
# 14526  great coffe good price subscript buyer buy mon...
# 14300  love faucet husband instal one old hous curren...
# 14299  gone treat dinner treat dog work run chanc los...
# 82884  love think littl expens everyday use refresh r...
# 82885  opinion best coconut water especi sinc made co...
# 15069  great coffe easi brew coffe great aroma good l...
# 43703  hubbi drink night month found fall deep sleep ...
# 13539  rooibo natur red tea someth person tast intere...
# 52220  great lunch kid enjoy snack also buy salt chip...
# 55100  nifti hot chocol disc ad warm milk milk altern...
# 89213  love flavor slight crunchi textur work well wh...
# 6548   order raisin multipl time alway great arriv ti...
# 60967  love assort differ countri origin fun tast dif...
# 43268  want food dog skin problem skin great improv s...
# 16026  everyday coffe choic good around crowd pleaser...
# 90340  spread serv chees platter goe well soft chees ...
# 76594  like product price point flavor strong overpow...
# 78715  tea good perfect price cant wrong product must...
# 50708  small salti tast good strong good thing packag...
# 76593  recent new keurig world ive tri hand flavor si...
# 22401  drink lot tea world far worst tast tea purchas...
# 56673  tri orang ice coffe morn realli like go place ...
# 37074  excel smooth tast one love chocol enjoy drink ...
# 5259   purchas product local store kid love quick eas...
#
# [87773 rows x 11 columns]

# %%
# Getting the Labels i.e the Score out of the dataframe.
y = time_sorted_data['Score']

# Removing the Labels i.e the Score Column from the dataframe as we wont need it to train a KNN.
x = time_sorted_data.drop(columns='Score',inplace=False)
#x.head()
y
x
# Out:
#            Id   ProductId          UserId  \
# 70688   76882  B00002N8SM  A32DW342WBJ6BX
# 1146     1245  B00002Z754  A29Z5PI9BW2PU3
# 1145     1244  B00002Z754  A3B8RCEI0FXFI6
# 28086   30629  B00008RCMI  A19E94CF5O1LY7
# 28087   30630  B00008RCMI  A284C7M23F0APC
# 61299   66610  B0000SY9U4  A3EEDHNHI4WNSH
# 38740   42069  B0000EIEQU  A1YMJX4YWCE6P4
# 38889   42227  B0000A0BS8  A1IU7S4HCK1XK0
# 94002                       0  1072656000
# 94024                      12  1073692800
# 94001                       0  1074124800
# 24220                       6  1075075200
# 94494                       9  1075161600
# 7427                        3  1075420800
# 25005                       0  1075680000
# 97771                       7  1075766400
# 94382                       5  1075939200
# ...                       ...         ...
# 42269                       0  1351209600
# 76059                       0  1351209600
# 25112                       0  1351209600
# 29158                       0  1351209600
# 87843                       0  1351209600
# 97624                       0  1351209600
# 14526                       0  1351209600
# 14300                       0  1351209600
# 14299                       0  1351209600
# 82884                       0  1351209600
# 82885                       0  1351209600
# 15069                       0  1351209600
# 43703                       0  1351209600
# 13539                       0  1351209600
# 52220                       0  1351209600
# 55100                       0  1351209600
# 89213                       0  1351209600
# 6548                        0  1351209600
# 60967                       0  1351209600
# 43268                       0  1351209600
# 16026                       0  1351209600
# 90340                       0  1351209600
# 76594                       0  1351209600
# 78715                       0  1351209600
# 50708                       0  1351209600
# 76593                       0  1351209600
# 22401                       0  1351209600
# 56673                       0  1351209600
# 37074                       0  1351209600
# 5259                        0  1351209600
#
#                                                  Summary  \
# 70688                             A sure death for flies
# 1146                                       Great Product
# 1145                      WOW Make your own 'slickers' !
# 28086         I've chewed this gum many times, but used?
# 28087                           Best sugarless gum ever!
# 61299                                              Yummy
# 38740                                  These limes rule!
# 38889                         I gave up on other coffees
# 38888                   Five stars if you like Starbucks
# 10992                             The fruits of my labor
# 28085                         Refreshing Mouth Freshner!
# 97546                                    *Yummy* *Spicy*
# 96196                                   Excellent Sauce!
# 62127                                            Try It!
# 87386                                 A very cute candy!
# 39671          Imparts wonderful, light flavor to dishes
# 48952                              Jelly Belly Overload!
# 24061                            I fell in love in Paris
# 86598       The best bread crumbs...you'll never go back
# 86599                        Essential for Tonkatsu, etc
# 81698                           everything is excellent!
# 94002                                        Simply Chai
# 94024                Chocolate Like You've Never Had It!
# 94001                                     Excellent Chai
# 24220              JUST LIKE GRANDMOTHER USED TO........
# 94494  Yes, You Can Eat It All In One Sitting and Sip...
# 7427                                    BEST BLUEBERRIES
# 25005                                    My Favorite Tea
# 97771        For those who enjoy playing with their food
# 94382      Best example of a blue cheese I've ever tried
# ...                                                  ...
# 42269                                    Great Irish Tea
# 76059                              Nice traditional chai
# 25112                                          Drink mix
# 29158                                          Delicious
# 87843              Michael Seasons Unsalted Potato Chips
# 97624  Ain't no coconut water better than Sun Tropics...
# 14526                                     Morning Coffee
# 14300                                   Love this faucet
# 14299                                      Dogs love it.
# 82884                                           Love it.
# 82885                                        I love this
# 15069                                       super coffee
# 43703                              Sleeping a lot better
# 13539                                          GREAT TEA
# 52220                                 Great for HS lunch
# 55100  Butler's chocolate is the real deal direct fro...
# 89213                                  Yummy and Healthy
# 6548                                          Delicious!
# 60967                                 So many varieties!
# 43268                                        Great food!
# 16026          Full- bodied without a bitter after-taste
# 90340                  The BEST fig spread on the market
# 76594                           Product is good, but....
# 78715                       5 Star Tea at a super price!
# 50708                                           Not bad.
# 76593                                   One of the best!
# 22401                                    bad tasting tea
# 56673                                             Chike!
# 37074                                   chocolate heaven
# 5259                                           DELICIOUS
#
#                                                     Text  \
# 70688  I bought a few of these after my apartment was...
# 1146   This was a really good idea and the final prod...
# 1145   I just received my shipment and could hardly w...
# 28086  Nothing against the product, but it does bothe...
# 28087  I love this stuff. It is sugar-free so it does...
# 61299  If you've never tried Kona coffee, Aloha Islan...
# 38740  Fresh limes are underappreciated, but a joy to...
# 38889  The grocery store has all kinds of &quot;gourm...
# 38888  This blend is one of Starbucks' gentler blends...
# 10992  When chatchi's favorite afternoon treat became...
# 28085  A tennis player hubby of mine got this pack on...
# 97546  Forget that store bought jerky.  Make your own...
# 96196  This sauce is excellent, and indeed spicy.  Th...
# 62127  If you've never had real Swiss fondue, you're ...
# 87386  This is definitely a cute product to order.  Y...
# 39671  I discovered these oils years ago, bought one ...
# 48952  I'm a huge fan of Jelly Belly jelly beans, so ...
# 24061  Yes, with this juice. Apparently I'm not the o...
# 86598  Panko bread crumbs are just awesome.  When use...
# 86599  This is the Japanese version of breadcrumb (pa...
# 81698  I highly recommend to have business with this ...
# 94002  I've tried many of packaged Chai products - li...
# 94024  I was first turned onto this chocolate when I ...
# 94001  I have searched for a great decaf chai and hav...
# 24220  For those who enjoy a rich spread for toast, c...
# 94494  And it is GOOD!!! You get a half pound of Cots...
# 7427   In the winter when fresh blueberries exceed ou...
# 25005  I love Sleepytime Tea!  I've been drinking it ...
# 97771  They're shaped like Legos and they taste like ...
# 94382  And that is no exagerration!  Roaring 40's Blu...
# ...                                                  ...
# 42269  We recently returned from a wonderful three we...
# 76059  I got hooked on this chai when I decided to gi...
# 25112  We love this drink mix it taste delicious and ...
# 29158  Individually packaged assorted rice crackers a...
# 87843  These are the best chips ever!  They are unsal...
# 97624  This is like young coconut in a can! It tastes...
# 14526  Great coffee at a good price. I'm a subscripti...
# 14300  Love this faucet.  My husband had installed th...
# 14299  This is the "all gone" treat after dinner.  It...
# 82884  I love this but think its a little to expensiv...
# 82885  It's is in my opinion the best coconut water o...
# 15069  Great coffee and so easy to brew.  This coffee...
# 43703  Hubby and I (both 63) have been drinking about...
# 13539  Rooibos Natural Red tea is something of a pers...
# 52220  Great for HS lunch, kid enjoy as a snack also,...
# 55100  Nifty hot chocolate discs added to your warm m...
# 89213  Loved the cranberry-like flavor and slightly c...
# 6548   I have ordered these raisins multiple times.  ...
# 60967  I love the assortment.  Different countries of...
# 43268  I wanted a food for a a dog with skin problems...
# 16026  This is my everyday coffee choice...a good all...
# 90340  This is my go to spread when I serve a cheese ...
# 76594  I like the product and the price point, but fo...
# 78715  This tea is very good and perfect for the pric...
# 50708  These are small and very salty. The taste is g...
# 76593  I am recently new to the Keurig world.  I've t...
# 22401  We drink a lot of tea... from all over the wor...
# 56673  Just tried the orange and iced coffee this mor...
# 37074  Excellent smooth taste. Any one who loves choc...
# 5259   Purchased this product at a local store in NY ...
#
#                                              CleanedText
# 70688  bought apart infest fruit fli hour trap mani f...
# 1146   realli good idea final product outstand use de...
# 1145   receiv shipment could hard wait tri product lo...
# 28086  noth product bother link top page buy use chew...
# 28087  love stuff doesnt rot gum tast good go buy gum...
# 61299  youv never tri kona coffe aloha island definit...
# 38740  fresh lime underappreci joy kitchen squirt lim...
# 38889  groceri store kind coffe laid one tri tast lik...
# 38888  blend one starbuck gentler blend like tast sta...
# 10992  chatchi favorit afternoon treat becam mysteri ...
# 28085  tenni player hubbi mine got pack rack opel cor...
# 97546  forget store bought jerki make premium jerki a...
# 96196  sauc excel inde spici brand also make mild ver...
# 62127  youv never real swiss fondu your realli miss s...
# 87386  definit cute product order get nice amount can...
# 39671  discov oil year ago bought one flavor thunders...
# 48952  huge fan jelli belli jelli bean realli enjoy g...
# 24061  yes juic appar person love drink lead orang ca...
# 86598  panko bread crumb awesom use bread make light ...
# 86599  japanes version breadcrumb portugues panko use...
# 81698  high recommend busi compani like job nice pric...
# 94002  ive tri mani packag chai product liquid dri so...
# 94024  first turn onto chocol visit privat mexican th...
# 94001  search great decaf chai final found excel made...
# 24220  enjoy rich spread toast crumpet english muffin...
# 94494  good get half pound cotswold english pub chees...
# 7427   winter fresh blueberri exceed food budget dri ...
# 25005  love sleepytim tea ive drink year sooth bed ta...
# 97771  theyr shape like lego tast like sweettart need...
# 94382  exagerr roar blue wonder mixtur strength subtl...
# ...                                                  ...
# 42269  recent return wonder three week excurs ireland...
# 76059  got hook chai decid give coffe still littl bit...
# 25112  love drink mix tast delici imposs find market ...
# 29158  individu packag assort rice cracker realli goo...
# 87843  best chip ever unsalt low sodium diet critic a...
# 97624  like young coconut tast like young coconut fre...
# 14526  great coffe good price subscript buyer buy mon...
# 14300  love faucet husband instal one old hous curren...
# 14299  gone treat dinner treat dog work run chanc los...
# 82884  love think littl expens everyday use refresh r...
# 82885  opinion best coconut water especi sinc made co...
# 15069  great coffe easi brew coffe great aroma good l...
# 43703  hubbi drink night month found fall deep sleep ...
# 13539  rooibo natur red tea someth person tast intere...
# 52220  great lunch kid enjoy snack also buy salt chip...
# 55100  nifti hot chocol disc ad warm milk milk altern...
# 89213  love flavor slight crunchi textur work well wh...
# 6548   order raisin multipl time alway great arriv ti...
# 60967  love assort differ countri origin fun tast dif...
# 43268  want food dog skin problem skin great improv s...
# 16026  everyday coffe choic good around crowd pleaser...
# 90340  spread serv chees platter goe well soft chees ...
# 76594  like product price point flavor strong overpow...
# 78715  tea good perfect price cant wrong product must...
# 50708  small salti tast good strong good thing packag...
# 76593  recent new keurig world ive tri hand flavor si...
# 22401  drink lot tea world far worst tast tea purchas...
# 56673  tri orang ice coffe morn realli like go place ...
# 37074  excel smooth tast one love chocol enjoy drink ...
# 5259   purchas product local store kid love quick eas...
#
# [87773 rows x 10 columns]

# %%
x_train = x.iloc[0:61441]
y_train = y.iloc[0:61441]
x_test =x.iloc[61441:87773]
y_test = y.iloc[61441:87773]
x_test
print ("Training Set - ", x_train.shape)
print ("Test Set - ", x_test.shape)
y_test.shape
# Out:
# Training Set -  (61441, 10)
# Test Set -  (26332, 10)
# (26332,)

# %% [markdown]
# # [4] Featurization

# %% [markdown]
# # [4.1] BAG OF WORDS

# %%
from sklearn.feature_extraction.text import CountVectorizer

count_vect = CountVectorizer()
bow_train= count_vect.fit_transform(x_train['CleanedText'].values)

bow_train.shape
# Out:
# (61441, 28686)

# %%
bow_test = count_vect.transform(x_test['CleanedText'].values)


bow_test.shape
# Out:
# (26332, 28686)

# %% [markdown]
# # [4.2] TF-IDF

# %%
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf_vect = TfidfVectorizer()
tfidf_train = tfidf_vect.fit_transform(x_train['CleanedText'].values)
tfidf_train.shape
# Out:
# (61441, 28686)

# %%
tfidf_test = tfidf_vect.transform(x_test['CleanedText'].values)

tfidf_test.shape
# Out:
# (26332, 28686)

# %% [markdown]
# # [5]NAIVE BAYES

# %% [markdown]
# # [5.1]APPLYING MULTINOMIAL NAIVE BAYES BOW

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score,confusion_matrix
from sklearn.model_selection import cross_val_score
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import GridSearchCV

# %%
tuned_parameters = [{'alpha': [10**-5, 10**-4, 10**-3, 10**-2, 10**-1, 10**0, 10**1, 10**2, 10**3, 10**4]}]
#Using GridSearchCV
model = GridSearchCV(MultinomialNB(), tuned_parameters,scoring='roc_auc', cv=3 ,n_jobs=-1, pre_dispatch=2)
model.fit(bow_train, y_train)
# Out:
# GridSearchCV(cv=3, error_score='raise',
#        estimator=MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True),
#        fit_params=None, iid=True, n_jobs=-1,
#        param_grid=[{'alpha': [1e-05, 0.0001, 0.001, 0.01, 0.1, 1, 10, 100, 1000, 10000]}],
#        pre_dispatch=2, refit=True, return_train_score='warn',
#        scoring='roc_auc', verbose=0)

# %%
best_alpha = model.best_params_['alpha']
C1 = best_alpha

print("Best hyper parameter to use is",best_alpha)
# Out:
# Best hyper parameter to use is 0.1

# %%
cv_scores  = model.cv_results_['mean_test_score']
train_scores  = model.cv_results_['mean_train_score']
cv_scores
# Out:
# array([0.80397384, 0.82432881, 0.84810746, 0.87352737, 0.89555799,
#        0.89483675, 0.71557836, 0.55074079, 0.52724058, 0.5208356 ])

# %% [markdown]
# # Plotting auc scores

# %%
import matplotlib.pyplot as plt
import math
plt.plot(np.log10(tuned_parameters[0]['alpha']),cv_scores,label="Validation AUC")
plt.plot(np.log10(tuned_parameters[0]['alpha']),train_scores,label="Train AUC")

plt.ylabel('AUC')
plt.xlabel('ALPHA')
plt.title('Hyperparameters Plot')
plt.legend()
plt.show()

# %%
mnb = MultinomialNB(alpha = best_alpha)

# fitting the model
mnb.fit(bow_train, y_train)

# predict the response
predictions = mnb.predict(bow_test)
predictions1= mnb.predict_proba(bow_test)
predictions1_train= mnb.predict_proba(bow_train)

# %%
tn, fp, fn, tp = confusion_matrix(y_test,predictions).ravel()
auc_final = roc_auc_score(y_test,predictions1[:,1])
fpr, tpr, thresholds = roc_curve(y_test, predictions1[:,1])
fpr_tr, tpr_tr, thresholds_tr = roc_curve(y_train,predictions1_train[:,1])
print(auc_final)
# Out:
# 0.9028797875210971

# %% [markdown]
# # plotting roc curve for train and test

# %%
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(fpr, tpr,label="ROC ON Test")
plt.plot(fpr_tr, tpr_tr,label="ROC ON Train")
plt.title('ROC Curve')
plt.legend()
plt.show()

# %% [markdown]
# # PLOTTING CONFUSION MATRIX

# %%
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt
array = [[(tn),(fp)], [(fn),(tp)]]
print(array)
df_cm = pd.DataFrame(array, ['Actual No','Actual Yes'],
                  ['Predicted No','Predicted Yes'])
plt.figure(figsize=(9, 6))
sns.heatmap(df_cm, annot=True,fmt='d', cmap = "GnBu")
df_cm
# Out:
# [[3095, 1462], [1384, 20391]]
#             Predicted No  Predicted Yes
# Actual No           3095           1462
# Actual Yes          1384          20391

# %% [markdown]
# # FEATURE IMPORTANCE

# %% [markdown]
# # Top 20 FEATURES FOR POSITIVE CLASS

# %%
S=mnb.feature_log_prob_[1,:].ravel().argsort()[::-1]
M=mnb.feature_log_prob_[1,:].ravel()[S]
X=M[0:20]
feature_names=np.array(count_vect.get_feature_names())
L=feature_names[S]

Y=L[0:20]
O=pd.DataFrame({'features': Y,
 'score': X})
O
# Out:
#    features     score
# 0      like -4.386321
# 1      tast -4.528675
# 2      good -4.618159
# 3      love -4.653578
# 4    flavor -4.654492
# 5     great -4.714958
# 6       one -4.760067
# 7       use -4.835716
# 8       tri -4.901733
# 9   product -4.923876
# 10      tea -4.932858
# 11    coffe -4.985588
# 12     food -5.038565
# 13      get -5.055929
# 14     make -5.067404
# 15      eat -5.313066
# 16      dog -5.314418
# 17    would -5.324351
# 18     time -5.370480
# 19      buy -5.377548

# %% [markdown]
# # TOP 20 FEATURES FOR NEGATIVE CLASS

# %%
S=mnb.feature_log_prob_[0,:].ravel().argsort()[::-1]
M=mnb.feature_log_prob_[0,:].ravel()[S]
X=M[0:20]
feature_names=np.array(count_vect.get_feature_names())
L=feature_names[S]

Y=L[0:20]
O=pd.DataFrame({'features': Y,
 'score': X})
O
# Out:
#    features     score
# 0      tast -4.210161
# 1      like -4.273977
# 2   product -4.477767
# 3       one -4.726714
# 4    flavor -4.791325
# 5     would -4.869703
# 6       tri -4.881372
# 7     coffe -5.031666
# 8      good -5.041950
# 9       use -5.109655
# 10     food -5.157052
# 11      get -5.164381
# 12      buy -5.172200
# 13    order -5.274024
# 14     dont -5.288126
# 15      dog -5.295498
# 16     even -5.353902
# 17      tea -5.394460
# 18   amazon -5.404312
# 19      box -5.407618

# %% [markdown]
# # [5.2] APPLYING MULTINOMIAL NAIVE BAYES TF-IDF

# %%
tuned_parameters = [{'alpha': [10**-5, 10**-4, 10**-3, 10**-2, 10**-1, 10**0, 10**1, 10**2, 10**3, 10**4]}]
#Using GridSearchCV
model = GridSearchCV(MultinomialNB(), tuned_parameters,scoring='roc_auc', cv=3 ,n_jobs=-1, pre_dispatch=2)
model.fit(tfidf_train, y_train)
# Out:
# GridSearchCV(cv=3, error_score='raise',
#        estimator=MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True),
#        fit_params=None, iid=True, n_jobs=-1,
#        param_grid=[{'alpha': [1e-05, 0.0001, 0.001, 0.01, 0.1, 1, 10, 100, 1000, 10000]}],
#        pre_dispatch=2, refit=True, return_train_score='warn',
#        scoring='roc_auc', verbose=0)

# %%
best_alpha = model.best_params_['alpha']
C1 = best_alpha

print("Best hyper parameter to use is",best_alpha)
# Out:
# Best hyper parameter to use is 0.1

# %%
cv_scores  = model.cv_results_['mean_test_score']
train_scores  = model.cv_results_['mean_train_score']
cv_scores
# Out:
# array([0.79418084, 0.81793696, 0.84830524, 0.88097123, 0.89986245,
#        0.86847172, 0.72941947, 0.67031646, 0.65273065, 0.6482362 ])

# %% [markdown]
# # PLOTTING AUC SCORES

# %%
import matplotlib.pyplot as plt
import math
plt.plot(np.log10(tuned_parameters[0]['alpha']),cv_scores,label="Validation AUC")
plt.plot(np.log10(tuned_parameters[0]['alpha']),train_scores,label="Train AUC")

plt.ylabel('AUC')
plt.xlabel('ALPHA')
plt.title('Hyperparameters Plot')
plt.legend()
plt.show()

# %%
mnb = MultinomialNB(alpha = best_alpha)

# fitting the model
mnb.fit(tfidf_train, y_train)

# predict the response
predictions = mnb.predict(tfidf_test)
predictions1= mnb.predict_proba(tfidf_test)
predictions1_train= mnb.predict_proba(tfidf_train)

# %%
tn, fp, fn, tp = confusion_matrix(y_test,predictions).ravel()
auc_final = roc_auc_score(y_test,predictions1[:,1])
fpr, tpr, thresholds = roc_curve(y_test, predictions1[:,1])
fpr_tr, tpr_tr, thresholds_tr = roc_curve(y_train,predictions1_train[:,1])
print(auc_final)
# Out:
# 0.9162657064603552

# %% [markdown]
# # PLOTTING ROC CURVE FOR TRAIN AND TEST

# %%
plt.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
plt.plot(fpr, tpr,label="ROC ON Test")
plt.plot(fpr_tr, tpr_tr,label="ROC ON Train")
plt.title('ROC Curve')
plt.legend()
plt.show()

# %% [markdown]
# # PLOTTING CONFUSION MATRIX

# %%
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt
array = [[(tn),(fp)], [(fn),(tp)]]
print(array)
df_cm = pd.DataFrame(array, ['Actual No','Actual Yes'],
                  ['Predicted No','Predicted Yes'])
plt.figure(figsize=(9, 6))
sns.heatmap(df_cm, annot=True,fmt='d', cmap = "GnBu")
df_cm
# Out:
# [[1045, 3512], [90, 21685]]
#             Predicted No  Predicted Yes
# Actual No           1045           3512
# Actual Yes            90          21685

# %% [markdown]
# # FEATURE IMPORTANCE

# %% [markdown]
# # TOP 20 FEATURES FOR POSITIVE CLASS

# %%
S=mnb.feature_log_prob_[1,:].ravel().argsort()[::-1]
M=mnb.feature_log_prob_[1,:].ravel()[S]
X=M[0:20]
feature_names=np.array(tfidf_vect.get_feature_names())
L=feature_names[S]

Y=L[0:20]
O=pd.DataFrame({'features': Y,
 'score': X})
O
# Out:
#    features     score
# 0      love -5.053812
# 1     great -5.066216
# 2      like -5.121515
# 3      good -5.128480
# 4      tast -5.155489
# 5       tea -5.198591
# 6    flavor -5.205143
# 7     coffe -5.212788
# 8   product -5.371397
# 9       one -5.386322
# 10      use -5.411824
# 11      tri -5.474286
# 12      dog -5.554322
# 13     food -5.569690
# 14     make -5.571906
# 15      get -5.579737
# 16    price -5.640719
# 17     best -5.655485
# 18      buy -5.673573
# 19   amazon -5.713464

# %% [markdown]
# # TOP 20 FEATURES FOR NEGATIVE CLASS

# %%
S=mnb.feature_log_prob_[0,:].ravel().argsort()[::-1]
M=mnb.feature_log_prob_[0,:].ravel()[S]
X=M[0:20]
feature_names=np.array(tfidf_vect.get_feature_names())
L=feature_names[S]

Y=L[0:20]
O=pd.DataFrame({'features': Y,
 'score': X})
O
# Out:
#       features     score
# 0         tast -4.878471
# 1         like -5.024635
# 2      product -5.090900
# 3        coffe -5.338928
# 4        would -5.387048
# 5       flavor -5.392887
# 6          one -5.430700
# 7          tri -5.498566
# 8          buy -5.565765
# 9        order -5.596775
# 10         box -5.667200
# 11        dont -5.698882
# 12        good -5.701116
# 13         dog -5.727202
# 14         get -5.745884
# 15        food -5.772052
# 16  disappoint -5.776720
# 17        even -5.789217
# 18         tea -5.792316
# 19         use -5.797964

# %% [markdown]
# # CONCLUSIONS

# %%
from prettytable import PrettyTable

    
x = PrettyTable()

x.field_names = ["Vectorizer", "Optimal_alpha", "AUC"]

x.add_row(["BOW",0.1,0.902])
x.add_row(["TFIDF",0.1,0.916])
print(x)
# Out:
# +------------+---------------+-------+
# | Vectorizer | Optimal_alpha |  AUC  |
# +------------+---------------+-------+
# |    BOW     |      0.1      | 0.902 |
# |   TFIDF    |      0.1      | 0.916 |
# +------------+---------------+-------+
